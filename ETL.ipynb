# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *
from pyspark import SparkConf, SparkContext

# %%
spark = SparkSession \
    .builder \
    .appName("MiniProjct") \
    .config("spark.some.config.option", "some-value") \
    .getOrCreate()

# %%
df = spark.read.option('header','true').csv('/FileStore/tables/Harris.csv')

# %%
df.printSchema()

# %%
df.write.partitionBy('MAIL_ZIP').mode('overwrite').parquet('/FileStore/address.parquet')
